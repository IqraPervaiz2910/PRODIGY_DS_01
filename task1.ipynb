# %% [markdown]
# # 1. Dataset Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_26346.csv', skiprows=4)

# Preview the dataset
print(df[['Country Name', '2023']].head())
# Out:
#                   Country Name         2023
# 0                        Aruba     107359.0
# 1  Africa Eastern and Southern  750503764.0
# 2                  Afghanistan   41454761.0
# 3   Africa Western and Central  509398589.0
# 4                       Angola   36749906.0

# %% [markdown]
# # 2. Prepare the data for plotting

# %%
# Extract relevant columns
pop_2023 = df[['Country Name', '2023']].dropna()

# Convert population to numeric (in case it's stored as string)
pop_2023['2023'] = pd.to_numeric(pop_2022['2023'])

# View summary stats
print(pop_2023['2023'].describe())
# Out:
# count    2.650000e+02
# mean     3.287886e+08
# std      1.018589e+09
# min      9.816000e+03
# 25%      1.827816e+06
# 50%      1.064485e+07
# 75%      6.661761e+07
# max      8.061876e+09
# Name: 2023, dtype: float64

# %% [markdown]
# # 3. Create the histogram

# %%
plt.figure(figsize=(10, 6))
plt.hist(pop_2023['2023'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Population Sizes by Country (2023)')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.grid(True)
plt.show()

# %% [markdown]
# # Bar Chart for Top 10 Most Populous Countries

# %%
top10 = pop_2023.sort_values(by='2023', ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top10['Country Name'], top10['2023'], color='teal')
plt.title('Top 10 Most Populous Countries (2023)')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
